# %%
import sys
sys.path.append('../../personal_pkgs')

from korean_crawling_bundles import *

from konlpy.tag import *
okt = Okt()
import datetime
from IPython.display import display

import re
import numpy as np
import pandas as pd
from pprint import pprint
from konlpy.tag import Hannanum

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# spacy for lemmatization
import spacy

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %% [markdown]
# stopwords는 불필요한 단어, 즉 조사나 관사들을 없애는 툴이다.

# %%
stop_words = list(pd.read_csv('kor_stop_words.csv').T.iloc[:1,:].values[0])
stop_words[:10]
# Out:
# ['아', '휴', '아이구', '아이쿠', '아이고', '어', '나', '우리', '저희', '따라']

# %% [markdown]
# # 전체 데이터프레임 병합하기

# %%
naver_df = pd.read_csv('../../folder/'+'{}_with_link_naver.csv'.format(str(datetime.datetime.now().month) + str(datetime.datetime.now().day),index=False))
daum_df = pd.read_csv('../../folder/'+'{}_with_link_daum.csv'.format(str(datetime.datetime.now().month) + str(datetime.datetime.now().day),index=False))
daum_df = daum_df.loc[:,['title','link','content']]

df = pd.concat([naver_df,daum_df],axis=0)
df.reset_index(drop=True,inplace=True)
df.tail()
# Out:
#                                 title  \
# 770       롯데, 손해보험·카드 매각..'제휴는 필수 옵션'
# 771    일자리 창출·혁신 기업, 공공부문 입찰 쉬워진다(종합)
# 772    '광주형 일자리' 투자 협상 기로..막판 돌파구 찾을까
# 773     [롯데 금융철수]② '카드+손보' 패키지 매각 이유는
# 774  [롯데 금융철수]① BNK금융 지분도 전량 매각..시기는?
#
#                                                   link  \
# 770  http://m.finance.daum.net/m/news/news_content....
# 771  http://m.finance.daum.net/m/news/news_content....
# 772  http://m.finance.daum.net/m/news/news_content....
# 773  http://m.finance.daum.net/m/news/news_content....
# 774  http://m.finance.daum.net/m/news/news_content....
#
#                                                content
# 770   【서울=뉴시스】표주연 기자 = 롯데그룹이 롯데손해보험과 롯데카드를 매각하기로 했다...
# 771  (서울=뉴스1) 박승주 기자한재준 기자 = 정부가 신기술·신제품에 대한 공공구매를 ...
# 772  (광주=연합뉴스) 장덕종 기자 = '광주형 일자리' 사업의 핵심인 현대자동차 완성차...
# 773  (서울=뉴스1) 김현동 기자 = 롯데그룹이 롯데카드 매각이라는 결단을 내렸다. 공정...
# 774  (서울=뉴스1) 장도민 기자 = 롯데그룹이 일반지주회사로 전환하면서 금산분리 원칙에...

# %% [markdown]
# # 병합한 데이터 프레임에서 중복되는 기사 내용 없애주기

# %%
append_ls,append_idx = [],[]
for idx,i in enumerate(df['title']) : 
    if i not in append_ls:
        append_ls.append(i)
        append_idx.append(idx)

# %%
df = df.loc[append_idx]
# df.reset_index(drop=True,inplace=True)
df.tail()
# Out:
#                                     title  \
# 732   소상공인연합회 "KT 상대 집단소송 지원..미온대응시 불매운동"
# 733  민주 "더는 양보없다..내줄 떡 없다"..野에 예산심사 복귀 압박
# 734       GM, 금융위기 이후 최대 규모 구조조정..한국 공장은?
# 735         기업 경기전망 22개월 만에 최저..제조업 부진 여파
# 736          기업 경기전망, 현 정부 들어 '최저치'로 떨어졌다
#
#                                                   link  \
# 732  http://m.finance.daum.net/m/news/news_content....
# 733  http://m.finance.daum.net/m/news/news_content....
# 734  http://m.finance.daum.net/m/news/news_content....
# 735  http://m.finance.daum.net/m/news/news_content....
# 736  http://m.finance.daum.net/m/news/news_content....
#
#                                                content
# 732  (서울=연합뉴스) 김연숙 기자 = 지난 24일 발생한 KT 서울 아현지사 통신구 화...
# 733  (서울=연합뉴스) 차지연 기자 = 더불어민주당은 27일 자유한국당과 바른미래당이 '...
# 734  AP 블룸버그통신 등에 따르면 GM은 북미지역에서 총 1만4700명을 감원할 계획이...
# 735  (서울=연합뉴스) 김준억 기자 = 기업들의 12월 경기전망이 22개월 만에 최저 수...
# 736  (서울=뉴스1) 류석우 기자 = 기업들의 12월 경기전망이 현 정부 들어 가장 악화...

# %%
df.fillna('0',inplace=True)
#결측치를 0으로 바꿔준다.

# %%
df['content'] = [i.replace('  ','') for i in df['content'].values]

# %% [markdown]
# ________

# %% [markdown]
# # Tuning_process

# %%
# Convert to list
data = df.content.values.tolist()

# Remove Emails
data = [re.sub('\S*@\S*\s?', '', sent) for sent in data]

# Remove distracting single quotes
data = [re.sub("\'", "", sent) for sent in data]

# 뒤에 부분의 저자에 관한 내용을 가능한 만큼 잘라준다.
data = [val[:re.search('Copyrights|ⓒ|▶',val).start()] if ('Copyrights' in val) or ('ⓒ' in val) or ("▶" in val) else val for val in data]

# 대괄호 안에 저자의 이름이 나와있는 경우를 없애준다.
data = [re.sub('\[.+\]','',val) for val in data]

pprint(data[0])
# Out:
# (' 신한은행이 베트남에서 현지 기업과 한인 상공인 교민들을 대상으로 내년 베트남 경제 전망을 조명하는 세미나를 개최했다.신한은행은 지난 '
#  '26일과 27일(현지시간) 신한베트남은행과 함께 ‘2019년 글로벌 및 베트남 경제 전망 세미나’를 진행했다.이 행사는 베트남시장에 대한 '
#  '전망과 경제동향 부동산 시장 전망과 세제 등의 내용으로 구성됐다. 현지의 한인 기업가와 근로자 교민 등 총 400명이 참석해 한국과 '
#  '베트남 부동산 시장의 발전상과 세무정보 내년 베트남 시장의 전망 등에 대한 강연을 들었다.세미나는 하노이와 호치민에서 한 차례씩 총 두 '
#  '차례 진행됐다. 신한은행은 현지 기업과 교민들의 사업계획 수립에 도움을 주기 위해 지난 2016년 하반기부터 경제 전망 세미나를 '
#  '진행해왔다. 매년 2차례씩 진행하는 현지 세미나는 한인상공인연합회가 공동으로 주최하면서 자연스럽게 베트남 내 한인들의 비즈니스 네트워크를 '
#  '쌓는 모임으로 자리잡았다. 신한은행 자산관리(WM)그룹의 IPS 산하 투자자산전략부와 신한베트남은행의 협력을 통해 2016년 9월부터 '
#  '현지고객 5000명에게 투자 동향에 대한 정보를 e-메일 등으로 전달해왔다.신한베트남은행은 지난해 말 베트남에서 호주계 은행인 '
#  '안즈(ANZ)의 리테일 부문을 인수한 후 전국에 30개 점포를 둔 베트남 최대 외국계 은행으로 올라섰다. 신한PWM은 전담직원의 세심한 '
#  '고객관리와 특화상품 제공 등을 기반으로 베트남에서 하노이 3곳 호치민 4곳 등 총 7개 지점으로 영역을 확대했다.이창구 신한은행 부행장은 '
#  '“앞으로도 베트남 뿐만 아니라 중국 인도네시아 인도 캐나다 미국 등 현지 법인이 진출해 있는 주요 거점에서 고객이 궁금해 하는 내용을 '
#  '중심으로 글로벌 세미나를 확대 시행할 예정이다”라고 전했다.- ')

# %%
from pykospacing import spacing
# Out:
# Using TensorFlow backend.

# %%
import warnings
warnings.filterwarnings("error")

# %%
# %%time

spacing_ls = []

for idx,val in enumerate(data) : 
    if idx % 100 ==0 : print('{}th index is done!'.format(idx))
    try : 
         spacing_ls.append(','.join([spacing(val) for val in val.split(".")]).replace(",",''))
    except : spacing_ls.append(val)
# Out:
# 0th index is done!
# 100th index is done!
# 200th index is done!
# 300th index is done!
# 400th index is done!
# 500th index is done!
# 600th index is done!
# 700th index is done!
# CPU times: user 8min 56s, sys: 2min 11s, total: 11min 7s
# Wall time: 2min 43s

# %%
data = spacing_ls.copy()

# %% [markdown]
# # tokenization process

# %% [markdown]
# - 정규식 표현을 통해서 문장 내에 이메일과 기타 특수 문자들을 없애주었지만, 여전히 난잡해보인다.
# - LDA 알고리즘을 사용하기 위해서는, 문장들을 단어들의 묶음으로 변환시켜주는 과정이 필요하다.
# - 이러한 과정을 Tokenization 이라고 한다.

# %%
# %time data_words = [okt.nouns(val) for val in data]
print(data_words[:1])
# Out:
# CPU times: user 37.7 s, sys: 0 ns, total: 37.7 s
# Wall time: 25.1 s
# [['신한은행', '베트남', '현지', '기업', '한인', '상공', '교민', '대상', '내년', '베트남', '경제', '전망', '조명하', '세미나', '개최', '신한은행', '지난', '현지', '시간', '신한', '베트남', '은행', '글로벌', '및', '베트남', '경제', '전망', '세미나', '를', '진행', '행사', '베트남', '시장', '대한', '전망', '경제', '동향', '부동산', '시장', '전망', '세제', '등', '내용', '구성', '현지', '한인', '기업가', '근로자', '교민', '등', '총', '명', '참석', '한국', '베트남', '부동산', '시장', '발전', '상과', '세무', '정보', '내년', '베트남', '시장', '전망', '등', '대한', '강연', '세미나', '하노이', '호치민', '차례', '총', '두', '차례', '진행', '신한은행', '현지', '기업', '교민', '사업', '계획', '수립', '도움', '주기', '위해', '지난', '하반기', '경제', '전망', '세미나', '진행', '매년', '차례', '진행', '현지', '세미나', '인상', '공인', '연합', '회', '공동', '주최', '자연', '베트남', '내', '한인', '비즈니스', '네트워크', '모임', '자리', '신한은행', '자산', '관리', '그룹', '투자', '자산', '전략', '부와', '신한', '베트남', '은행', '협력', '통해', '현지', '고객', '명', '투자', '동향', '대한', '정보', '메일', '등', '전달', '베트남', '은행', '지난해', '말', '베트남', '호주', '은행', '안', '의', '리테일', '부문', '인수', '후', '전국', '개', '점포', '베트남', '최대', '외국', '은행', '신한', '은', '전담', '직원', '세심', '고객', '관리', '특', '상품', '제공', '등', '기반', '베트남', '하노이', '곳', '호치민', '곳', '등', '총', '개', '지점', '영역', '확대', '창구', '신한은행', '부행', '앞', '베트남', '뿐', '중국', '인도네시아', '인도', '캐나다', '미국', '등', '현지', '법인', '진출', '주요', '거점', '고객', '내용', '중심', '글로벌', '세미나', '확대', '시행', '예정', '전']]

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  
        # deacc=True removes punctuations
        # 구두점(말끝에 찍는 쉼표나 점들을 의미) 을 없애주는 것이다.

gensim_data_words = list(sent_to_words(data))

print(gensim_data_words[:1])
# Out:
# [['신한은행이', '베트남에서', '현지', '기업과', '한인', '상공인', '교민들을', '대상으로', '내년', '베트남', '경제', '전망을', '조명하는', '세미나를', '개최했다신한은행은', '지난', '일과', '현지시간', '신한', '베트남은행과', '함께', '글로벌', '베트남', '경제', '전망', '세미나', '진행했다이', '행사는', '베트남', '시장에', '대한', '전망과', '경제동향', '부동산', '시장', '전망과', '세제', '등의', '내용으로', '구성됐다현지의', '한인', '기업가와', '근로자', '교민', '명이', '참석해', '한국과', '베트남', '부동산', '시장의', '발전상과', '세무정보', '내년', '베트남', '시장의', '전망', '등에', '대한', '강연을', '들었다세미나는', '하노이와', '호치민에서', '차례씩', '차례', '진행됐다신한은행은', '현지', '기업과', '교민들의', '사업', '계획', '수립에', '도움을', '주기', '위해', '지난', '하반기부터', '경제', '전망', '세미나를', '진행해왔다매년', '차례씩', '진행하는', '현지', '세미나는', '한인상공인연합회가', '공동으로', '주최하면서', '자연스럽게', '베트남', '한인들의', '비즈니스', '네트워크를', '쌓는', '모임으로', '자리', '잡았다신한은행', '자산관리', 'wm', '그룹의', 'ips', '산하', '투자자산', '전략부와', '신한', '베트남은행의', '협력을', '통해', '월부터', '현지', '고객', '명에게', '투자', '동향에', '대한', '정보를', '메일', '등으로', '전달해왔다신한베트남은행은', '지난해', '베트남에서', '호주계', '은행인', '안즈', 'anz', '리테일', '부문을', '인수한', '전국에', '점포를', '베트남', '최대', '외국계', '은행으로', '올라섰다신한', 'pwm은', '전담', '직원의', '세심한', '고객', '관리와', '특화상품', '제공', '등을', '기반으로', '베트남에서', '하노이', '호치민', '지점으로', '영역을', '확대했다이창구', '신한은행', '부행장은', '앞으로도', '베트남', '뿐만', '아니라', '중국', '인도네시아', '인도', '캐나다', '미국', '현지', '법인이', '진출해', '있는', '주요', '거점에서', '고객이', '궁금해', '하는', '내용을', '중심으로', '글로벌', '세미나를', '확대', '시행할', '예정이다', '라고', '전했다']]

# %% [markdown]
# ### Bigram , Trigram 모델 만들기
# - Bigram : 문서에서 함께 자주 등장하는 2개의 단어
# - Trigram : 문서에서 함께 자주 등장하는 3개의 단어
# - ‘front_bumper’, ‘oil_leak’, ‘maryland_college_park’ etc.
# - Phrases : 모델을 빌드한다.
# - min_count , threshold : Pharases 의 중요한 두 개의 파라미터
#     - min_count (float, optional) : Ignore all words and bigrams with total collected count lower than this value.
#     - threshold (float, optional) : Represent a score threshold for forming the phrases (higher means fewer phrases). A phrase of words a followed by b is accepted if the score of the phrase is greater than threshold. Heavily depends on concrete scoring-function, see the scoring parameter.

# %%
warnings.filterwarnings("ignore")

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
print(trigram_mod[bigram_mod[data_words[0]]])
# Out:
# ['신한은행', '베트남', '현지', '기업', '한인', '상공', '교민', '대상', '내년', '베트남', '경제', '전망', '조명하', '세미나', '개최', '신한은행', '지난', '현지_시간', '신한', '베트남', '은행', '글로벌', '및', '베트남', '경제', '전망', '세미나', '를', '진행', '행사', '베트남', '시장', '대한', '전망', '경제', '동향', '부동산', '시장', '전망', '세제', '등', '내용', '구성', '현지', '한인', '기업가', '근로자', '교민', '등', '총', '명', '참석', '한국', '베트남', '부동산', '시장', '발전', '상과', '세무', '정보', '내년', '베트남', '시장', '전망', '등', '대한', '강연', '세미나', '하노이', '호치민', '차례', '총', '두', '차례', '진행', '신한은행', '현지', '기업', '교민', '사업', '계획', '수립', '도움', '주기', '위해', '지난', '하반기', '경제', '전망', '세미나', '진행', '매년', '차례', '진행', '현지', '세미나', '인상', '공인', '연합_회', '공동', '주최', '자연', '베트남', '내', '한인', '비즈니스', '네트워크', '모임', '자리', '신한은행', '자산', '관리', '그룹', '투자', '자산', '전략', '부와', '신한', '베트남', '은행', '협력', '통해', '현지', '고객', '명', '투자', '동향', '대한', '정보', '메일', '등', '전달', '베트남', '은행', '지난해', '말', '베트남', '호주', '은행', '안', '의', '리테일', '부문', '인수', '후', '전국', '개', '점포', '베트남', '최대', '외국', '은행', '신한', '은', '전담', '직원', '세심', '고객', '관리', '특', '상품', '제공', '등', '기반', '베트남', '하노이', '곳', '호치민', '곳', '등', '총', '개', '지점', '영역', '확대', '창구', '신한은행', '부행', '앞', '베트남', '뿐', '중국', '인도네시아', '인도', '캐나다', '미국', '등', '현지', '법인', '진출', '주요', '거점', '고객', '내용', '중심', '글로벌', '세미나', '확대', '시행', '예정', '전']

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

# %%
# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

data_lemmatized = data_words_bigrams.copy()

print(data_lemmatized[:1])
# Out:
# [['신한은행', '베트남', '현지', '기업', '한인', '상공', '교민', '대상', '내년', '베트남', '경제', '전망', '조명하', '세미나', '개최', '신한은행', '지난', '현지', '신한', '베트남', '은행', '글로벌', '베트남', '경제', '전망', '세미나', '진행', '행사', '베트남', '시장', '대한', '전망', '경제', '동향', '부동산', '시장', '전망', '세제', '내용', '구성', '현지', '한인', '기업가', '근로자', '교민', '참석', '한국', '베트남', '부동산', '시장', '발전', '상과', '세무', '정보', '내년', '베트남', '시장', '전망', '대한', '강연', '세미나', '하노이', '호치민', '차례', '차례', '진행', '신한은행', '현지', '기업', '교민', '사업', '계획', '수립', '도움', '주기', '위해', '지난', '하반기', '경제', '전망', '세미나', '진행', '매년', '차례', '진행', '현지', '세미나', '인상', '공인', '연합', '공동', '주최', '자연', '베트남', '한인', '비즈니스', '네트워크', '모임', '자리', '신한은행', '자산', '관리', '그룹', '투자', '자산', '전략', '부와', '신한', '베트남', '은행', '협력', '통해', '현지', '고객', '투자', '동향', '대한', '정보', '메일', '전달', '베트남', '은행', '지난해', '베트남', '호주', '은행', '리테일', '부문', '인수', '전국', '점포', '베트남', '최대', '외국', '은행', '신한', '전담', '직원', '세심', '고객', '관리', '상품', '제공', '기반', '베트남', '하노이', '호치민', '지점', '영역', '확대', '창구', '신한은행', '부행', '베트남', '중국', '인도네시아', '인도', '캐나다', '미국', '현지', '법인', '진출', '주요', '거점', '고객', '내용', '중심', '글로벌', '세미나', '확대', '시행', '예정']]

# %% [markdown]
# - LDA 모델에 들어가야 하는 두 가지 입력변수는 딕셔너리와(id2word) 코퍼스(corpus)이다.
# - gensim 은 문서 내에 있는 단어별로 유니크한 아이디를 할당해준다.
# - 아래의 각각의 엘리먼트 튜플당 의미하는 것은 [word_id,word_frequency] 이다.

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# View
print(corpus[:1])
# Out:
# [[(0, 1), (1, 1), (2, 1), (3, 4), (4, 1), (5, 3), (6, 1), (7, 1), (8, 2), (9, 3), (10, 1), (11, 1), (12, 1), (13, 2), (14, 1), (15, 2), (16, 1), (17, 2), (18, 2), (19, 1), (20, 1), (21, 3), (22, 1), (23, 2), (24, 1), (25, 1), (26, 1), (27, 1), (28, 1), (29, 1), (30, 1), (31, 14), (32, 2), (33, 1), (34, 1), (35, 1), (36, 1), (37, 1), (38, 1), (39, 1), (40, 1), (41, 1), (42, 6), (43, 1), (44, 1), (45, 1), (46, 4), (47, 1), (48, 3), (49, 5), (50, 1), (51, 1), (52, 1), (53, 1), (54, 1), (55, 5), (56, 1), (57, 1), (58, 1), (59, 1), (60, 1), (61, 2), (62, 1), (63, 1), (64, 1), (65, 1), (66, 1), (67, 6), (68, 1), (69, 2), (70, 1), (71, 1), (72, 1), (73, 1), (74, 1), (75, 1), (76, 1), (77, 2), (78, 1), (79, 1), (80, 1), (81, 1), (82, 4), (83, 3), (84, 1), (85, 1), (86, 1), (87, 1), (88, 1), (89, 2), (90, 2), (91, 1), (92, 1), (93, 3), (94, 1), (95, 7), (96, 1), (97, 1), (98, 2), (99, 2)]]

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=5, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
# Print the Keyword in the 10 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.025*"카드" + 0.019*"금융" + 0.016*"보험" + 0.014*"피해" + 0.013*"서비스" + '
#   '0.012*"은행" + 0.008*"결제" + 0.008*"책임" + 0.008*"상품" + 0.007*"대응"'),
#  (1,
#   '0.008*"기술" + 0.008*"기관" + 0.007*"고객" + 0.006*"보고서" + 0.006*"경제" + '
#   '0.006*"세계" + 0.006*"인증" + 0.005*"서비스" + 0.005*"포럼" + 0.005*"정책"'),
#  (2,
#   '0.007*"기준" + 0.007*"임대주택" + 0.007*"예산" + 0.006*"경우" + 0.006*"사업" + '
#   '0.006*"한국" + 0.006*"승객" + 0.006*"문제" + 0.005*"항공" + 0.005*"지역"'),
#  (3,
#   '0.019*"금융" + 0.017*"정부" + 0.012*"기업" + 0.009*"관련" + 0.009*"테크" + 0.008*"투자" '
#   '+ 0.008*"공장" + 0.008*"미국" + 0.008*"회사" + 0.007*"자동차"'),
#  (4,
#   '0.019*"롯데" + 0.015*"기업" + 0.014*"상승" + 0.014*"전망" + 0.012*"경기" + 0.010*"서울" '
#   '+ 0.010*"기록" + 0.009*"기준" + 0.008*"개월" + 0.008*"수준"')]

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -7.696671278142311
#
# Coherence Score:  0.3353755589347297

# %%
def format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=data):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=ldamallet , corpus=corpus, texts=data)

#ldamallet 파라미터를 optimal_params 로 바꿔주는 시퀀스로 업데이트할 것!

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

# Show
df_dominant_topic.head(10)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0             1.0              0.5661
# 1            1             4.0              0.6603
# 2            2             4.0              0.4444
# 3            3             0.0              0.4995
# 4            4             1.0              0.2325
# 5            5             1.0              0.2325
# 6            6             3.0              0.5043
# 7            7             0.0              0.4317
# 8            8             3.0              0.5790
# 9            9             4.0              0.4381
#
#                                   Keywords  \
# 0   금융, 은행, 투자, 통해, 회장, 한국, 산업, 성장, 경영, 사업
# 1  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
# 2  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
# 3  정부, 미국, 거래, 증권, 삼성, 대한, 중국, 서울, 대해, 위원회
# 4   금융, 은행, 투자, 통해, 회장, 한국, 산업, 성장, 경영, 사업
# 5   금융, 은행, 투자, 통해, 회장, 한국, 산업, 성장, 경영, 사업
# 6  금융, 기업, 테크, 관련, 회사, 포인트, 전망, 도입, 보험, 대출
# 7  정부, 미국, 거래, 증권, 삼성, 대한, 중국, 서울, 대해, 위원회
# 8  금융, 기업, 테크, 관련, 회사, 포인트, 전망, 도입, 보험, 대출
# 9  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
#
#                                                 Text
# 0  신한은행이 베트남에서 현지 기업과 한인 상공인 교민들을 대상으로 내년 베트남 경제 ...
# 1  디지털 코어(CORE) 뱅크 전환을 추진 중인 IBK기업은행이 새로운 디지털 마케팅...
# 2  롯데카드가 28일 전국 롯데면세점과 롭스 오프라인 매장에서 앱 카드 QR 결제 방식...
# 3  【서울=뉴시스】이재준 기자 = 중국 인민은행은 28일 위안화 기준치를 1달러 =69...
# 4                             전문가들의 내년 투자전략이 알고 싶다면?
# 5                             전문가들의 내년 투자전략이 알고 싶다면?
# 6  대부업법상 최고금리의 일몰 조항이 폐지되면서 내년부터 이자 상한선(현행 24%)을 ...
# 7  공정거래위원회는 김형배 카르텔 조사국장(사진)이 경제협력개발기구(OECD) 경쟁위원...
# 8  (서울=뉴스1 ) 박주평 기자 = 한국P2P금융협회(이하 협회) 회원사들의 평균 연...
# 9  롯데카드가 전국 롯데면세점 롭스 오프라인 매장에 앱카드 QR 결제 방식의 ‘큐알페이...

# %%
recommendation_df = df_dominant_topic.sort_values(by='Topic_Perc_Contrib',ascending=False)
recommendation_df.reset_index(drop=True,inplace=True)
recommendation_df
# Out:
#      Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            432             1.0              0.7925
# 1            409             1.0              0.7909
# 2            309             1.0              0.7890
# 3            480             1.0              0.7888
# 4            380             1.0              0.7885
# 5            233             1.0              0.7764
# 6            268             1.0              0.7758
# 7            212             2.0              0.7744
# 8            269             2.0              0.7710
# 9            245             1.0              0.7665
# 10           509             1.0              0.7631
# 11           687             0.0              0.7620
# 12           155             1.0              0.7561
# 13           396             2.0              0.7556
# 14           246             2.0              0.7426
# 15           322             2.0              0.7389
# 16           648             1.0              0.7375
# 17           307             1.0              0.7373
# 18           474             2.0              0.7353
# 19           391             2.0              0.7348
# 20           213             1.0              0.7302
# 21           495             2.0              0.7302
# 22           351             2.0              0.7286
# 23           372             2.0              0.7276
# 24           594             3.0              0.7254
# 25           344             2.0              0.7245
# 26           126             3.0              0.7233
# 27           115             3.0              0.7222
# 28           447             2.0              0.7219
# 29           657             2.0              0.7184
# ..           ...             ...                 ...
# 679          518             4.0              0.2157
# 680          216             4.0              0.2157
# 681          252             4.0              0.2157
# 682          387             4.0              0.2157
# 683           19             4.0              0.2157
# 684          631             4.0              0.2157
# 685          416             4.0              0.2157
# 686          386             4.0              0.2157
# 687          626             4.0              0.2157
# 688          327             4.0              0.2157
# 689          417             4.0              0.2135
# 690           13             4.0              0.2135
# 691          459             4.0              0.2119
# 692          458             4.0              0.2119
# 693          183             1.0              0.2113
# 694          177             4.0              0.2113
# 695          178             4.0              0.2113
# 696          180             4.0              0.2113
# 697          181             4.0              0.2113
# 698          194             4.0              0.2113
# 699          456             4.0              0.2099
# 700          141             1.0              0.2092
# 701          455             4.0              0.2078
# 702          176             1.0              0.2070
# 703          179             1.0              0.2070
# 704          457             4.0              0.2058
# 705          202             0.0              0.2000
# 706          506             0.0              0.2000
# 707           58             0.0              0.2000
# 708          628             0.0              0.2000
#
#                                     Keywords  \
# 0     금융, 은행, 투자, 통해, 회장, 한국, 산업, 성장, 경영, 사업
# 1     금융, 은행, 투자, 통해, 회장, 한국, 산업, 성장, 경영, 사업
# 2     금융, 은행, 투자, 통해, 회장, 한국, 산업, 성장, 경영, 사업
# 3     금융, 은행, 투자, 통해, 회장, 한국, 산업, 성장, 경영, 사업
# 4     금융, 은행, 투자, 통해, 회장, 한국, 산업, 성장, 경영, 사업
# 5     금융, 은행, 투자, 통해, 회장, 한국, 산업, 성장, 경영, 사업
# 6     금융, 은행, 투자, 통해, 회장, 한국, 산업, 성장, 경영, 사업
# 7    카드, 롯데, 보험, 금융, 손해, 그룹, 매각, 수수료, 업계, 영업
# 8    카드, 롯데, 보험, 금융, 손해, 그룹, 매각, 수수료, 업계, 영업
# 9     금융, 은행, 투자, 통해, 회장, 한국, 산업, 성장, 경영, 사업
# 10    금융, 은행, 투자, 통해, 회장, 한국, 산업, 성장, 경영, 사업
# 11   정부, 미국, 거래, 증권, 삼성, 대한, 중국, 서울, 대해, 위원회
# 12    금융, 은행, 투자, 통해, 회장, 한국, 산업, 성장, 경영, 사업
# 13   카드, 롯데, 보험, 금융, 손해, 그룹, 매각, 수수료, 업계, 영업
# 14   카드, 롯데, 보험, 금융, 손해, 그룹, 매각, 수수료, 업계, 영업
# 15   카드, 롯데, 보험, 금융, 손해, 그룹, 매각, 수수료, 업계, 영업
# 16    금융, 은행, 투자, 통해, 회장, 한국, 산업, 성장, 경영, 사업
# 17    금융, 은행, 투자, 통해, 회장, 한국, 산업, 성장, 경영, 사업
# 18   카드, 롯데, 보험, 금융, 손해, 그룹, 매각, 수수료, 업계, 영업
# 19   카드, 롯데, 보험, 금융, 손해, 그룹, 매각, 수수료, 업계, 영업
# 20    금융, 은행, 투자, 통해, 회장, 한국, 산업, 성장, 경영, 사업
# 21   카드, 롯데, 보험, 금융, 손해, 그룹, 매각, 수수료, 업계, 영업
# 22   카드, 롯데, 보험, 금융, 손해, 그룹, 매각, 수수료, 업계, 영업
# 23   카드, 롯데, 보험, 금융, 손해, 그룹, 매각, 수수료, 업계, 영업
# 24   금융, 기업, 테크, 관련, 회사, 포인트, 전망, 도입, 보험, 대출
# 25   카드, 롯데, 보험, 금융, 손해, 그룹, 매각, 수수료, 업계, 영업
# 26   금융, 기업, 테크, 관련, 회사, 포인트, 전망, 도입, 보험, 대출
# 27   금융, 기업, 테크, 관련, 회사, 포인트, 전망, 도입, 보험, 대출
# 28   카드, 롯데, 보험, 금융, 손해, 그룹, 매각, 수수료, 업계, 영업
# 29   카드, 롯데, 보험, 금융, 손해, 그룹, 매각, 수수료, 업계, 영업
# ..                                       ...
# 679  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
# 680  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
# 681  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
# 682  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
# 683  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
# 684  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
# 685  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
# 686  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
# 687  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
# 688  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
# 689  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
# 690  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
# 691  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
# 692  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
# 693   금융, 은행, 투자, 통해, 회장, 한국, 산업, 성장, 경영, 사업
# 694  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
# 695  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
# 696  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
# 697  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
# 698  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
# 699  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
# 700   금융, 은행, 투자, 통해, 회장, 한국, 산업, 성장, 경영, 사업
# 701  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
# 702   금융, 은행, 투자, 통해, 회장, 한국, 산업, 성장, 경영, 사업
# 703   금융, 은행, 투자, 통해, 회장, 한국, 산업, 성장, 경영, 사업
# 704  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
# 705  정부, 미국, 거래, 증권, 삼성, 대한, 중국, 서울, 대해, 위원회
# 706  정부, 미국, 거래, 증권, 삼성, 대한, 중국, 서울, 대해, 위원회
# 707  정부, 미국, 거래, 증권, 삼성, 대한, 중국, 서울, 대해, 위원회
# 708  정부, 미국, 거래, 증권, 삼성, 대한, 중국, 서울, 대해, 위원회
#
#                                                   Text
# 0    <아이뉴스24> 신한금융그룹은 26일 프랑스 파리에서 열린 유엔 환경계획 금융부문(...
# 1    신한금융그룹은 지난 26일 프랑스 파리에서 열린 ‘유엔 환경계획 금융부문(UN En...
# 2    (서울=뉴스1) 장도민 기자 = 조용병 신한금융 회장이 UN 금융 행사에서 글로벌 ...
# 3    신한금융지주는 지난 26일 프랑스 파리에서 열린 유엔 환경계획 금융부문(UNEP F...
# 4    신한금융지주는 지난 26일 프랑스 파리에서 열린 유엔 환경계획 금융부문(UNEP F...
# 5    신한금융그룹(회장 조용병)이 26일 프랑스 파리에서 열린 ‘유엔 환경계획 금융부문(...
# 6    신한금융그룹이 유엔 환경계획 금융부문 글로벌 라운드 테이블(UN Env ironme...
# 7    <아이뉴스24> 롯데가 결국 금융업에서 철수한다는 뜻을 공식화하면서 롯데카드와 롯데...
# 8    롯데그룹의 금융계열사 롯데손해보험과 롯데카드가 인수·합병(M&A) 시장에 나왔다두 ...
# 9    신한금융그룹이 유엔 환경계획 금융부문 글로벌 라운드 테이블(UN Env ironme...
# 10   신한금융그룹이 26일(현지시간) 프랑스 파리에서 열린 유엔 환경계획 금융부문(UNE...
# 11   【서울=뉴시스】임종명 강지은 오제일 기자 =국회 예산결산특별위원회가 예산안조정소위 ...
# 12   신 한·하나·KB금융지주 등이 국내외 금융시장에서 성장과 투자 키워드로 ‘ESR(환...
# 13   <아이뉴스24> 폭염과 보험사고 등 악재가 겹치면서 1~3분기 손보업계의 보험 영업...
# 14   롯데손해보험과 롯데카드가 인수·합병(M&A) 시장에 매물로 나오면서 경영 위기에 내...
# 15   (서울=뉴스1) 김영신 기자 = 롯데그룹이 내놓는 롯데카드와 롯데손해보험을 누가 인...
# 16   【울산=뉴시스】구미현 기자 = UNIST(울산과학기술원) 소속 교수 7명이 2018...
# 17   신한금융그룹(회장 조용병)이 26일 프랑스 파리에서 열린 유엔 환경계획 금융부문(이...
# 18   <아이뉴스24> 김창권 롯데카드 대표와 김현수 롯데손해보험 대표가 각각 임직원들에게...
# 19   올 3·4분기 누적 손해보험회사의 손해액이 1조8000억원에 달하면서 손보사의 순이...
# 20    KDB산업은행은 27일 서울 여의도 콘래드호텔에서 신규시장 개척 및 기술혁신을 통...
# 21   각각 임직원들에게 글 보내…"고용안정·처우 보장 노력"(서울=연합뉴스) 구 정모 홍...
# 22   (서울=뉴스1) 김현동 기자 = 롯데그룹이 롯데카드 매각이라는 결단을 내렸다공정거래...
# 23   롯데그룹이 지주사 체제 전환의 걸림돌이었던 롯데카드와 롯데손해보험을 끝내 매각하기로...
# 24   (서울=연합뉴스) 김수현 기자 = 조선업 회복 영향으로 이번 달 기업 체감경기가 소...
# 25   롯데그룹이 지주사 체제 전환을 위해 롯데카드와 롯데손해보험을 매각하기로 결정하면서 ...
# 26   【서울=뉴시스】조현아 기자 = 제조업 경기실사지수가 이달 5개월 만에 반등한 것으로...
# 27   경기 하락 우려에도 불구 조선 등 일부 업종의 업황 개선으로 기업들의 체감 경기가 ...
# 28   롯데그룹이 금융계열사 매각에 나선 가운데 롯데카드와 손해보험 대표들이 임직원들에게 ...
# 29   롯데그룹이 금융업에서 손을 뗀다지주사 체제로 전환한 롯데는 공정거래법 준수를 위해 ...
# ..                                                 ...
# 679                                             [기사 제보
# 680                                             [기사 제보
# 681                                             [기사 제보
# 682                                             [기사 제보
# 683                                             [기사 제보
# 684                                               ◀ 앵커
# 685                                             [기사 제보
# 686                                             [기사 제보
# 687                                               ◀ 앵커
# 688                                             [기사 제보
# 689                                             [기사 제보
# 690                                             [기사 제보
# 691               당사의 허락 없이 본 글과 사진의 무단 전재 및 재배포를 금합니다
# 692               당사의 허락 없이 본 글과 사진의 무단 전재 및 재배포를 금합니다
# 693                                             ※ 저작권자
# 694                                             ※ 저작권자
# 695                                             ※ 저작권자
# 696                                             ※ 저작권자
# 697                                             ※ 저작권자
# 698                                             ※ 저작권자
# 699               당사의 허락 없이 본 글과 사진의 무단 전재 및 재배포를 금합니다
# 700                                             ※ 저작권자
# 701               당사의 허락 없이 본 글과 사진의 무단 전재 및 재배포를 금합니다
# 702                                             ※ 저작권자
# 703                                             ※ 저작권자
# 704               당사의 허락 없이 본 글과 사진의 무단 전재 및 재배포를 금합니다
# 705                                                  [
# 706                                                  [
# 707                                                  [
# 708                                                  0
#
# [709 rows x 5 columns]

# %%
duplicate_ls = []
duplicate_idx = []
for idx,val in enumerate(recommendation_df['Dominant_Topic'].values):
    if val not in duplicate_ls:
        duplicate_ls.append(val)
        duplicate_idx.append(idx)
        if len(duplicate_ls) == 5 : break

# %%
display(recommendation_df.loc[duplicate_idx])
display(df.loc[recommendation_df.loc[duplicate_idx]['Document_No'].values])
# Out:
#     Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0           432             1.0              0.7925
# 7           212             2.0              0.7744
# 11          687             0.0              0.7620
# 24          594             3.0              0.7254
# 73          676             4.0              0.6692
#
#                                    Keywords  \
# 0    금융, 은행, 투자, 통해, 회장, 한국, 산업, 성장, 경영, 사업
# 7   카드, 롯데, 보험, 금융, 손해, 그룹, 매각, 수수료, 업계, 영업
# 11  정부, 미국, 거래, 증권, 삼성, 대한, 중국, 서울, 대해, 위원회
# 24  금융, 기업, 테크, 관련, 회사, 포인트, 전망, 도입, 보험, 대출
# 73  고객, 서비스, 상품, 결제, 제공, 지역, 통해, 기자, 사용, 피해
#
#                                                  Text
# 0   <아이뉴스24> 신한금융그룹은 26일 프랑스 파리에서 열린 유엔 환경계획 금융부문(...
# 7   <아이뉴스24> 롯데가 결국 금융업에서 철수한다는 뜻을 공식화하면서 롯데카드와 롯데...
# 11  【서울=뉴시스】임종명 강지은 오제일 기자 =국회 예산결산특별위원회가 예산안조정소위 ...
# 24  (서울=연합뉴스) 김수현 기자 = 조선업 회복 영향으로 이번 달 기업 체감경기가 소...
# 73  공정거래위원회는 소비자 피해를 최소화하기 위해 상조업체에 자본금 증액을 압박하고 있...
#                                       title  \
# 432             재계의 요청에도 공정거래법 개정안 국무회의서 의결
# 212                  보험자본 건정성 선진화 추진단 1차 회의
# 687      제주 삼다수 "최악 피했다"..'생산공장 재가동' 결정(상보)
# 594  현대해상, '2018 스포트라이트 어워즈' 연차보고서 부문 금상 수상
# 676      현대중 노조, 부당노동행위 항의 엿새째 파업..고용부 앞 집회
#
#                                                   link  \
# 432  https://m.news.naver.com/read.nhn?oid=029&aid=...
# 212  https://m.news.naver.com/read.nhn?oid=421&aid=...
# 687  http://m.finance.daum.net/m/news/news_content....
# 594  https://m.news.naver.com/read.nhn?oid=015&aid=...
# 676  http://m.finance.daum.net/m/news/news_content....
#
#                                                content
# 432  중대·명백한 경성담합(가격담합 생산량 조절 시장분할 입찰담합 등 중대담합)에 대해서...
# 212  (서울=뉴스1) 이재명 기자 = 김용범 금융위원회 부위원장이 27일 오후 서울 세종...
# 687  (서울=뉴스1) 신건웅 기자 = 근로자 사망사고로 가동이 전면 중간됐던 제주개발공사...
# 594  [ 차은지 기자] 현대해상은 '2018 스포트라이트 어워즈(Spotlight Awa...
# 676  (울산=연합뉴스) 김근주 기자 = 현대중공업 노조는 27일 사측 부당노동행위에 항의...

# %%
recommendation_df = df.loc[recommendation_df.loc[duplicate_idx]['Document_No'].values].iloc[:,:2]
recommendation_df
# Out:
#                                       title  \
# 432             재계의 요청에도 공정거래법 개정안 국무회의서 의결
# 212                  보험자본 건정성 선진화 추진단 1차 회의
# 687      제주 삼다수 "최악 피했다"..'생산공장 재가동' 결정(상보)
# 594  현대해상, '2018 스포트라이트 어워즈' 연차보고서 부문 금상 수상
# 676      현대중 노조, 부당노동행위 항의 엿새째 파업..고용부 앞 집회
#
#                                                   link
# 432  https://m.news.naver.com/read.nhn?oid=029&aid=...
# 212  https://m.news.naver.com/read.nhn?oid=421&aid=...
# 687  http://m.finance.daum.net/m/news/news_content....
# 594  https://m.news.naver.com/read.nhn?oid=015&aid=...
# 676  http://m.finance.daum.net/m/news/news_content....

# %%
recommendation_df['link'].tolist()
# Out:
# ['https://m.news.naver.com/read.nhn?oid=029&aid=0002494542&sid1=101&sid2=259&mode=LS2D',
#  'https://m.news.naver.com/read.nhn?oid=421&aid=0003712913&sid1=101&sid2=259&mode=LS2D',
#  'http://m.finance.daum.net/m/news/news_content.daum?type=main&sub_type=&docid=MD20181127150015521&section=&limit=30&page=10',
#  'https://m.news.naver.com/read.nhn?oid=015&aid=0004051786&sid1=101&sid2=259&mode=LS2D',
#  'http://m.finance.daum.net/m/news/news_content.daum?type=main&sub_type=&docid=MD20181127160640357&section=&limit=30&page=9']

# %% [markdown]
# # Telegram Service

# %%
import telegram # 텔레그램 모듈을 임포트합니다.

my_token = '717292107:AAGuwGQIlMnr-LlhtH5xqR4Zud8GyyKXbQY' # 토큰을 변수에 저장합니다.

bot = telegram.Bot(token = my_token) # bot을 선언합니다.

chat_id = bot.getUpdates()[-1].message.chat.id

bot.sendMessage(chat_id=chat_id, text='안녕하세요. 좋은 아침입니다. {}토픽 별 기사 5개 추천해드리겠습니다.'.format(\
str(datetime.datetime.now().month)+' 월 ' + str(datetime.datetime.now().day)+' 일 '))

for news in recommendation_df['link'].tolist() :
    bot.sendMessage(chat_id = chat_id, text=news)

# %%
# import telegram
# import pickle

# my_token = pickle.load( open('../../pw.pickle', 'rb'))
# my_token = my_token

# bot = telegram.Bot(token = my_token) #봇을 생성합니다.

# chat_id = bot.getUpdates()[-1].message.chat.id

# bot.sendMessage(chat_id=chat_id, text='안녕하세요. 좋은 아침입니다. {}토픽 별 기사 5개 추천해드리겠습니다.'.format(\
# str(datetime.datetime.now().month)+' 월 ' + str(datetime.datetime.now().day)+' 일 '))

# for news in recommendation_df['link'].tolist() :
#     bot.sendMessage(chat_id = chat_id, text=news)
